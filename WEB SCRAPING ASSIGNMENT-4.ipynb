# %% [markdown]
# # Q.No.1

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
Rank = []
Name = []
Artist = []
Upload_Date = []
Views = []

rank = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
for i in rank[:30]:
    Rank.append(i.text)

name = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
for i in name[:30]:
    Name.append(i.text)
    
art = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
for i in art[:30]:
    Artist.append(i.text)

ud = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")
for i in ud[:30]:
    Upload_Date.append(i.text)

views = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
for i in views[:30]:
    Views.append(i.text)

# %%
print(len(Rank), len(Name), len(Artist), len(Upload_Date), len(Views))
# Out:
# 30 30 30 30 30

# %%
# Creating the DataFrame
import pandas as pd
Data1 = pd.DataFrame({})
Data1['Rank'] = Rank
Data1['Name'] = Name
Data1['Artist'] = Artist
Data1['Upload Date'] = Upload_Date
Data1['Views'] = Views
Data1
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[5]
# 2    3.                       "Johny Johny Yes Papa"[11]
# 3    4.                               "Shape of You"[12]
# 4    5.                              "See You Again"[14]
# 5    6.                                  "Bath Song"[19]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[20]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[21]
# 8    9.                                "Uptown Funk"[22]
# 9   10.                "Phonics Song with Two Words"[23]
# 10  11.                              "Gangnam Style"[24]
# 11  12.                             "Dame Tu Cosita"[29]
# 12  13.                                      "Sugar"[30]
# 13  14.                                      "Sorry"[31]
# 14  15.                                       "Roar"[32]
# ...

# %% [markdown]
# # Q.No.2

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st
#  ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://www.bcci.tv/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
fixtures = driver.find_element_by_xpath("/html/body/nav/div/div[2]/ul[1]/li[2]/a")
driver.get(fixtures.get_attribute('href'))
time.sleep(2)

# %%
#Creating empty lists for storing the scrapped data
Match=[]
Series=[]
Place=[]
Date=[]
Time=[]

#Scrapping the data having the match name
name=driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
for i in name:
    Match.append(i.text)

#Scrapping the data having the series name
series=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[2]")
for i in series:
    Series.append(i.text)
    
#Scrapping the data having the place of match
place=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)
    
#Scrapping the data having the match date
date=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']/div/span")  #Only date
month=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']/div/div/span[1]")  #Month
for i in range(len(date)):
    Date.append(date[i].text + month[i].text)  #Appending date and month texts together
    
#Scrapping the data having match time
time=driver.find_elements_by_xpath("//div[@class='fixture__full-date']/div/span[2]")
for i in time:
    Time.append(i.text)

# %%
#Creating a Dataframe for the scrapped data
import pandas as pd
fixtures=pd.DataFrame({})
fixtures['Match name']=Match
fixtures['Series']=Series
fixtures['Place']=Place
fixtures['Date']=Date
fixtures['Time']=Time
fixtures
# Out:
# Empty DataFrame
# Columns: [Match name, Series, Place, Date, Time]
# Index: []

# %% [markdown]
# # Q.No.3

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://www.guru99.com/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
driver.find_element_by_xpath("//div[@class='srch']/span[8]/a").click()
driver.find_element_by_xpath("//table[@class='table']/tbody/tr[34]/td/a").click()

# %%
Name = []
Description = []

name = driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
for i in name:
    Name.append(i.text)

description = driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
for i in description:
    Description.append(i.text)

# %%
print(len(Name), len(Description))
# Out:
# 41 41

# %%
# Creating DataFrame
selenium_exception = pd.DataFrame({})
selenium_exception['Name'] = Name
selenium_exception['Description'] = Description
selenium_exception
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# # Q.No.4

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'http://statisticstimes.com/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
Economy = driver.find_element_by_xpath("//div[@class='navbar']/div[2]/div/a[3]")
try:
    Economy.click()
except ElementNotInteractableException:
    driver.get(Economy.get_attribute('href'))

# %%
GDP = driver.find_element_by_xpath("//div[@style='float:left;background-color:seashell;width:400px;height:800px;']/ul/li[1]")
try:
    GDP.click()
except ElementNotInteractableException:
    driver.get(GDP.get_attribute('href'))

# %%
Rank = [] 
State = [] 
GSDP19_20 = [] 
GSDP18_19 = [] 
Share19_20 = [] 
GDP = []

rank = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]")
for i in rank:
    Rank.append(i.text)

state = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]")
for i in state:
    State.append(i.text)

for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]"):
    GSDP19_20.append(i.text)
    
for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]"):
    GSDP18_19.append(i.text)

for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]"):
    Share19_20.append(i.text)

for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]"):
    GDP.append(i.text)

# %%
print(len(Rank), len(State), len(GSDP19_20), len(GSDP18_19), len(Share19_20), len(GDP))
# Out:
# 66 66 66 66 66 66

# %%
# Creating DataFrame
import pandas as pd
gdp=pd.DataFrame({})
gdp['Rank']=Rank
gdp['State']=State
gdp['GSDP19_20']=GSDP19_20
gdp['GSDP18_19']=GSDP18_19
gdp['Share19_20']=Share19_20
gdp['GDP($ billion)']=GDP
gdp
# Out:
#    Rank                      State  GSDP19_20  GSDP18_19 Share19_20  \
# 0     1                Maharashtra          -  2,632,792     13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208      8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764      8.39%
# 3     4                    Gujarat          -  1,502,899      7.96%
# 4     5                  Karnataka  1,631,977  1,493,127      7.91%
# ..  ...                        ...        ...        ...        ...
# 61   29                     Sikkim     28,391     25,141      0.15%
# 62   30                   Nagaland          -     24,534      0.15%
# 63   31          Arunachal Pradesh          -     22,488      0.13%
# 64   32                    Mizoram     24,424     20,947      0.13%
# 65   33  Andaman & Nicobar Islands          -          -          -
#
#    GDP($ billion)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# ..            ...
# ...

# %% [markdown]
# # Q.No.5

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://github.com/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
elements = driver.find_elements_by_xpath('//summary[@class = "HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block"]')
elements[1].click()
time.sleep(2)

elements1 = driver.find_elements_by_xpath('//li[@class = "edge-item-fix"]//a')

for i in elements1:
    link = i.get_attribute('href')
    if '/trending' in link:
        i.click()
        break
        
dicty = {}
dicty['Repositorytitle'] = []
dicty['Repositorydescription'] = []
dicty['Contributorscount'] = []
dicty['Language'] = []

elements2 = driver.find_elements_by_xpath('//h1[@class = "h3 lh-condensed"]//a')

for i in elements2:
    dicty['Repositorytitle'].append(i.text)
    
elements3 = driver.find_elements_by_xpath('//p[@class = "col-9 color-text-secondary my-1 pr-4"]')

for i in elements3:
    dicty['Repositorydescription'].append(i.text)

elements4 = driver.find_elements_by_xpath('//div[@class = "f6 color-text-secondary mt-2"]')

for i in elements4:
    dicty['Language'].append(i.text.split(" ")[0])
    dicty['Contributorscount'].append(i.text.split(" ")[2])

# %%
github_df = pd.DataFrame({'Repository title': dicty['Repositorytitle'], 'Repository description': dicty['Repositorydescription'], 
                          'Contributors count': dicty['Contributorscount'], 'Language': dicty['Language'],})
github_df
# Out:
# Empty DataFrame
# Columns: [Repository title, Repository description, Contributors count, Language]
# Index: []

# %% [markdown]
# # Q.No.6

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://www.billboard.com/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
Song_name = [] 
Artist_name = [] 
Last_week_rank = [] 
Peak_rank = []
Weeks_on_board = []

song_name = driver.find_elements_by_xpath("//*[@id='title-of-a-story']")
for i in song_name:
    if i.text is None:
        Song_name.append('-')
    else:
        Song_name.append(i.text)
        
artist = driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for j in artist:
    if j.text is None:
        Artist_name.append('-')
    else:
        Artist_name.append(j.text)

rank = driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for k in rank:
    if k.text is None:
        Last_week_rank.append('-')
    else:
        Last_week_rank.append(k.text)
        
peak = driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for l in peak:
    if l.text is None:
        Peak_rank.append('-')
    else:
        Peak_rank.append(l.text)

# %% [markdown]
# # Q.No.7

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://www.naukri.com/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
recruiters = driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]/a")
driver.get(recruiters.get_attribute('href'))
time.sleep(2)

# %%
search_jobs = driver.find_element_by_xpath("//input[@class='sugInp']")
search_jobs.send_keys('Data science')

search_button = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search_button.click()

# %%
Name = [] 
Designation = [] 
Company = [] 
Skills_they_hire = [] 
Location = []

name = driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
for i in name:
    Name.append(i.text)

designation = driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
for j in designation:
    Designation.append(j.text)
    
company = driver.find_elements_by_xpath("//p[@class='highlightable']/a[2]")
for k in company:
    Company.append(k.text)
    
skills = driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for l in skills:
    Skills_they_hire.append(l.text)
    
location = driver.find_elements_by_xpath("//small[@class='ellipsis']")
for m in location:
    Location.append(m.text)

# %%
print(len(Name), len(Designation), len(Company), len(Skills_they_hire), len(Location))
# Out:
# 50 50 50 50 48

# %%
# Creating DataFrame
import pandas as pd
DS_Jobs = pd.DataFrame({})
DS_Jobs['Name'] = Name[:48]
DS_Jobs['Designation'] = Designation[:48]
DS_Jobs['Company'] = Company[:48]
DS_Jobs['Skills_they_hire'] = Skills_they_hire[:48]
DS_Jobs['Location'] = Location[:48]
DS_Jobs
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# # Q.No.8

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-
# compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
Book_name = [] 
Author_name = []
Volumes_sold = [] 
Publisher = []
Genre = []

book_name = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in book_name:
    Book_name.append(i.text)

author_name = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
for j in author_name:
    Author_name.append(j.text)
    
volumes_sold = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
for k in volumes_sold:
    Volumes_sold.append(k.text)
    
publisher = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
for l in publisher:
    Publisher.append(l.text)
    
genre  = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
for m in genre :
    Genre.append(m.text)

# %%
print(len(Book_name ), len(Author_name), len(Volumes_sold), len(Publisher), len(Genre))
# Out:
# 100 100 100 100 100

# %%
# Creating DataFrame
import pandas as pd
novels = pd.DataFrame({})
novels['Book name'] = Book_name 
novels['Author name'] = Author_name
novels['Volumes sold'] = Volumes_sold
novels['Publisher'] = Publisher
novels['Genre'] = Genre
novels
# Out:
#                                            Book name        Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %% [markdown]
# # Q.No.9

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
Name = []
Year_span = []
Genre = [] 
Run_time = [] 
Ratings = [] 
Votes = []

name = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for i in name:
    Name.append(i.text)
    
year = driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for j in year:
    Year_span.append(j.text)

genre = driver.find_elements_by_xpath("//span[@class='genre']")
for k in genre:
    Genre.append(k.text)
    
run = driver.find_elements_by_xpath("//span[@class='runtime']")
for l in run:
    Run_time.append(l.text)
    
ratings = driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")
for m in ratings:
    Ratings.append(m.text)
    
votes = driver.find_elements_by_xpath("//span[@name='nv']")
for n in votes:
    Votes.append(n.text)

# %%
print(len(Name), len(Year_span), len(Genre), len(Author_name), len(Run_time), len(Ratings), len(Votes))
# Out:
# 100 100 100 100 100 100 100

# %%
# Creating DataFrame
import pandas as pd
IMDB = pd.DataFrame({})
IMDB['Name'] = Name  
IMDB['Year span'] = Year_span
IMDB['Genre'] = Genre 
IMDB['Run time'] = Run_time 
IMDB['Ratings'] = Ratings
IMDB['Votes'] = Votes
IMDB
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  1,926,068
# ...

# %% [markdown]
# # Q.No. 10

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
# Solution:

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/acer/Downloads/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(0.5)

# URL
url = 'https://archive.ics.uci.edu/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
Datasets = driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
                                        
try:
    Datasets.click()
except ElementNotInteractableException:
    driver.get(Datasets.get_attribute('href'))

# %%
Dataset_name = []
Data_type = []
Task = [] 
Attribute_type = [] 
No_of_instances = [] 
No_of_attributes = []
Year = []

try:
    dataset_name = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in dataset_name:
        Dataset_name.append(i.text)
except NoSuchElementException:
    Dataset_name.append('-')
    
    
try:
    data_type = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for j in data_type[1:]:
        Data_type.append(j.text)
except NoSuchElementException:
    Data_type.append('-')
    

try:
    task = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for k in task[1:]:
        Task.append(k.text)
except NoSuchElementException:
    Task.append('-')
    
    
try:
    attribute_type = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for l in attribute_type[1:]:
        Attribute_type.append(l.text)
except NoSuchElementException:
    Attribute_type.append('-')
    
    
try:
    instances = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for m in instances[1:]:
        No_of_instances.append(m.text)
except NoSuchElementException:
    No_of_instances.append('-')
    
    
try:
    attributes = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for n in attributes[1:]:
        No_of_attributes.append(n.text)
except NoSuchElementException:
    No_of_attributes.append('-')
    

try:
    year = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for o in year[1:]:
        Year.append(o.text)
except NoSuchElementException:
    Year.append('-')

# %%
# Creating DataFrame
import pandas as pd
Datasets = pd.DataFrame({})
Datasets['Dataset name '] = Dataset_name   
Datasets['Data type'] = Data_type
Datasets['Task'] = Task
Datasets['Attribute type'] = Attribute_type 
Datasets['No. of instances'] = No_of_instances
Datasets['No. of attributes'] = No_of_attributes
Datasets['Year'] = Year
Datasets
# Out:
#                                          Dataset name   \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
